# %% [markdown]
# String Methods

# %%
a="Niranjan V"
print (a.upper())
print (a.lower())
print (a.capitalize()) #First letter to uppercase
print (a.title()) #First letter of each word to uppercase
print (a.swapcase())
print (a.casefold()) #Similar to lower() but more aggressive for certain languages
# Out:
# NIRANJAN V
# niranjan v
# Niranjan v
# Niranjan V
# nIRANJAN v
# niranjan v
