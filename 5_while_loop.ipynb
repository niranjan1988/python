# %% [markdown]
# # While

# %%
a=0
while (a!=10):
    print(a)
    a=int(input("Enter a number: "))
# Out:
# 0
# 1
# 2
# 3

# %%
list1 = [1,2,3,4,5]
item=0
while item<=4:
    item+=1
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5
