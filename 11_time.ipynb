# %% [markdown]
# # Time module

# %%
import time

print(time.time()) # returns the current time in seconds since the epoch (January 1, 1970, 00:00:00 UTC)
print(time.perf_counter()) # high resolution timer, used for measuring short durations
# Out:
# 1770796070.32243
# 20688.029743775
