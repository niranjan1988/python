# %%
def add_numbers(a, b):
    return a + b

result = add_numbers(5, 7)
print("The sum is:", result)
# Out:
# The sum is: 12

# %%
def multiply_numbers(a, b=1):
    return a * b

    result = multiply_numbers(5, 7)
    print("The product is:", result)

result = multiply_numbers(5)
print("The product with default b is:", result)
# Out:
# The product with default b is: 5

# %%
result = multiply_numbers(5,7)
print("The product is:", result)
# Out:
# The product is: 35
